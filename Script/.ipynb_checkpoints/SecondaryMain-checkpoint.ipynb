# %% [markdown]
# # In questo script recupero informazioni relative ai Trimming DAC dei FE RD53A e RD53B

# %%
# %run ./Functions/parseTxtCalib.ipynb #parsing del file txt. input: path; output: dataframe

# %% [markdown]
# ### Importo la funzione che si occupa di plottare gli istogrammi relativi al trimming DAC
# In input riceve la struttura dati che contiene le liste di dati (generate dalla funzione parseTxtCalib) e il titolo da dare al plot.
#
# Vengono plottati due istogrammi delle medie: uno per RD53A e uno per RD53B. Le medie sono il dato calcolato dal SW per calibrare il trimming DAC.

# %%
# %run ./Functions/plotHistMean.ipynb #plot istogrammi delle medie. input: datasource, titolo; output: plot due istogrammi

# %% [markdown]
# ### Importo la funzione che si occupa di plottare gli scan di soglia
# In input riceve la struttura dati che contiene le liste di dati (generate dalla funzione parseTxtCalib) e il titolo da dare al plot.
#
# Vengono plottati due grafici: uno per RD53A e uno per RD53B. I grafici sono ricavati mediante interpolazione dei punti ricavati dal file generato dal SW per calibrare il trimming DAC.

# %%
# %run ./Functions/plotFittingError.ipynb

# %% [markdown]
# ### Elaboro i dati esportati dal SW di calibrazione

# %%
data18 = parseTxtCalib('C:/Users/andre/Desktop/CMSAFE_test_AndreaGalliani/CMSAFE_calibs/calib_I_LDAC_18_0_soglia_1000_elettroni.txt')

# %%
plotFittingError(data18, '$I_{LDAC}$ = 18 $\mu$A')

# %%
plotHistMean(data18, '$I_{LDAC}$ = 18 $\mu$A')

# %%
path = saveButton()
# Out:
# Selected path: C:/Users/andre/Desktop/CMSAFE_test_AndreaGalliani
