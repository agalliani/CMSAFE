# %% [markdown]
# # HEATMAP

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
import matplotlib.patches as mpatches
from matplotlib.colors import LogNorm, Normalize

import seaborn as sns; sns.set_theme()


# %run ./Functions/selectFiles.ipynb #gestisce button e schermata di dialogo con il file system
# %run ./Functions/parseCalibs.ipynb #parsing dei file txt. input: path[]; output: dataframe[]
button = selectFiles() #è possibile selezionare più files
# Out:
# Selected files:
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_340_PREAMP_30_CD_50_LDAC_14_soglia_340.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_370_PREAMP_30_CD_50_LDAC_14_soglia_370.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_420_PREAMP_30_CD_50_LDAC_14_soglia_420.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_460_PREAMP_30_CD_50_LDAC_14_soglia_460.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_500_PREAMP_30_CD_50_LDAC_14_soglia_500.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_550_PREAMP_30_CD_50_LDAC_14_soglia_550.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_600_PREAMP_30_CD_50_LDAC_14_soglia_600.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_680_PREAMP_30_CD_50_LDAC_14_soglia_680.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_750_PREAMP_30_CD_50_LDAC_14_soglia_750.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_830_PREAMP_30_CD_50_LDAC_14_soglia_830.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_900_PREAMP_30_CD_50_LDAC_14_soglia_900.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_960_PREAMP_30_CD_50_LDAC_14_soglia_960.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_A_1000_PREAMP_30_CD_50_LDAC_14_soglia_1000.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_340_PREAMP_30_CD_50_LDAC_14_soglia_340.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_370_PREAMP_30_CD_50_LDAC_14_soglia_370.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_420_PREAMP_30_CD_50_LDAC_14_soglia_420.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_460_PREAMP_30_CD_50_LDAC_14_soglia_460.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_500_PREAMP_30_CD_50_LDAC_14_soglia_500.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_550_PREAMP_30_CD_50_LDAC_14_soglia_550.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_600_PREAMP_30_CD_50_LDAC_14_soglia_600.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_680_PREAMP_30_CD_50_LDAC_14_soglia_680.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_750_PREAMP_30_CD_50_LDAC_14_soglia_750.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_830_PREAMP_30_CD_50_LDAC_14_soglia_830.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_900_PREAMP_30_CD_50_LDAC_14_soglia_900.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_960_PREAMP_30_CD_50_LDAC_14_soglia_960.txt
# C:/Users/andre/Documents/CMSAFE/CMSAFE_calibs/test preamp 30 CD 50/noise_B_1000_PREAMP_30_CD_50_LDAC_14_soglia_1000.txt

# %%
paths = button.files

# %%
def getHits(file, start, end):
    channels = []
    counts = []
    with open (file, 'rt') as myfile:
        lines = myfile.readlines()
        for i in range(0, len(lines)):    
            line = lines[i].split()
            if(line[0].isdigit()):
                channels.append(int(line[0]))
                counts.append(int(line[1]))
    #a = pd.DataFrame(list(zip(channels, counts)), columns = ['Channel', "Counts"]) 
    return [counts[x:x+7] for x in range(start, end, 7)]

# %%
def plotHeatmap(fileA, fileB):

    noise_A = getHits(fileA, 16, 128)
    noise_B = getHits(fileB, 128, 240)
    
    model = os.path.basename(fileA[-7:-4])

    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey='row', figsize = (11, 11))
    fig.subplots_adjust(wspace=0.01)
    
    sns.heatmap(noise_A, ax = ax1, annot = True, fmt="d" , vmin=0,vmax = 36, xticklabels=False, yticklabels=False, square=True, cbar = False, cmap = "jet") #cmap="BuPu"
    fig.colorbar(ax1.collections[0],  ax=ax1, location = "left", use_gridspec=False, pad=0)

    sns.heatmap(noise_B, ax = ax2,annot = True, fmt="d", vmin=0, vmax = 36, xticklabels=False, yticklabels=False, square=True, cbar = False, cmap = "jet") #cmap="BuPu"
    fig.colorbar(ax2.collections[0], ax=ax2, location = "right", use_gridspec=False, pad=0)

    ax1.set_xlabel("RD53A")
    ax2.set_xlabel("RD53B")

    fig.suptitle('Noise Occupancy with threshold = '+ model + " electrons",fontsize=20, y = 0.92)
    
    plt.savefig('Heatmap noise soglia '+model, bbox_inches='tight')

    plt.show()

# %%
plotHeatmap(paths[0], paths[13])

# %%
plotHeatmap(paths[1], paths[14])

# %%
plotHeatmap(paths[2], paths[15])

# %%
plotHeatmap(paths[3], paths[16])

# %%
plotHeatmap(paths[4], paths[17])

# %%
plotHeatmap(paths[5], paths[18])

# %%
plotHeatmap(paths[6], paths[19])

# %%
plotHeatmap(paths[7], paths[20])

# %%
plotHeatmap(paths[8], paths[21])

# %%
plotHeatmap(paths[9], paths[22])

# %%
plotHeatmap(paths[10], paths[23])

# %%
plotHeatmap(paths[11], paths[24])

# %%
plotHeatmap(paths[12], paths[25])
